# %%
import pandas as pd
import numpy as np
#%matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
dF=pd.read_csv('EURUSD1440.csv',sep='\t')
dF
# Out:
#             Date   Time     Open     High      Low    Close  Volume
# 0     1994.02.01  00:00  0.57110  0.57380  0.56790  0.57260    1031
# 1     1994.02.02  00:00  0.57270  0.57330  0.56870  0.57300     891
# 2     1994.02.03  00:00  0.57200  0.57290  0.56870  0.57110     751
# 3     1994.02.04  00:00  0.57160  0.57280  0.56980  0.56980     421
# 4     1994.02.07  00:00  0.57030  0.57420  0.57020  0.57330     501
# 5     1994.02.08  00:00  0.57280  0.57760  0.57280  0.57360     881
# 6     1994.02.09  00:00  0.57520  0.57730  0.57490  0.57580     421
# 7     1994.02.10  00:00  0.57580  0.57800  0.57490  0.57490     531
# 8     1994.02.11  00:00  0.57520  0.57520  0.57260  0.57360     361
# 9     1994.02.14  00:00  0.57410  0.57420  0.57120  0.57170     361
# 10    1994.02.15  00:00  0.57190  0.57500  0.57150  0.57310     581
# 11    1994.02.16  00:00  0.57470  0.57600  0.57240  0.57510     681
# 12    1994.02.17  00:00  0.57560  0.57700  0.57490  0.57560     421
# ...

# %%
#dFrame.dropna(inplace=True)
#dFrame

# %%
dF.shape
# Out:
# (6321, 7)

# %%
print('Cierre Máx: ',dF['Close'].max())
print('Cierre Min:', dF['Close'].min())
# Out:
# Cierre Máx:  0.8818799999999999
# Cierre Min: 0.3907

# %%
dF.keys()
# Out:
# Index(['Date', 'Time', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
dF.head()
# Out:
#          Date   Time    Open    High     Low   Close  Volume
# 0  1994.02.01  00:00  0.5711  0.5738  0.5679  0.5726    1031
# 1  1994.02.02  00:00  0.5727  0.5733  0.5687  0.5730     891
# 2  1994.02.03  00:00  0.5720  0.5729  0.5687  0.5711     751
# 3  1994.02.04  00:00  0.5716  0.5728  0.5698  0.5698     421
# 4  1994.02.07  00:00  0.5703  0.5742  0.5702  0.5733     501

# %%
plt.plot(dF.Open,dF.Close, c="black", label="prediccion")

# %%
#dF.plot(subplots=True)
dF['Close'].plot()

# %%
#dF['Open'].plot()
